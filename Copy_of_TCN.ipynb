# %% [markdown]
# <a href="https://colab.research.google.com/github/thejolly911/MAJOR-PROJECT/blob/main/Copy_of_TCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Data and Needed Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Conv1D, LSTM,MaxPooling1D, AveragePooling1D, Concatenate, Input
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from datetime import datetime
from tensorflow.keras.models import Model # Use tensorflow.keras.models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Concatenate, Input # Use tensorflow.keras.layers
# Import plot_model from tensorflow.keras.utils
from tensorflow.keras.utils import plot_model
from keras import regularizers


df=pd.read_csv('/content/building-electrical-energy-daily-use-ubcv-2019-2021.csv')
columns = df.columns;

# %% [markdown]
# # **Data Preprocessing**
#
#
# # Filling NaN values by the mean of the column relative to it

# %%
for i in range(1,len(df. columns)-1):
    df[columns[i]] = df[columns[i]].fillna(df[columns[i]].mean());

# %% [markdown]
# # **Summing the Energy Consumption of all buildings for each day**

# %%
df["Total Energy Consumption"] = df[columns[1:]].sum(axis = 1);
# Out:
# <ipython-input-3-16302ae571fc>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["Total Energy Consumption"] = df[columns[1:]].sum(axis = 1);

# %% [markdown]
# # **Drop the Energy Consumption of individual buildings**

# %%
for i in range(1,len(columns)):
    df = df.drop(columns[i], axis = 1)

# %% [markdown]
# # **Transfer Date column into Datatime type**

# %%
for i in range(0,len(df["Date"])):
    df.loc[ i,'Date']= datetime.strptime(df["Date"].loc[i], '%m/%d/%Y');

# %% [markdown]
# # **Extracting Features from Date column**

# %%
df["Date"] = pd.to_datetime(df["Date"])

#Date features
df["Day"] = df["Date"].dt.dayofweek
df["Month"] = df["Date"].dt.month
df["Year"] = df["Date"].dt.year
df["Q"] = df["Date"].dt.quarter
df["Dayofyear"] = df["Date"].dt.dayofyear
df["Dayofmonth"] = df["Date"].dt.day
df["Weekofyear"] = df["Date"].dt.isocalendar().week

# %%
df["Holiday"] = 0;# Column that includes where a specific day is a Holdiay or not based on the Holiday Days in the United states
for i in range(0,len(df["Dayofmonth"])):
    if(df['Dayofmonth'][i] == 1 and df["Month"][i] == 1):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 21 and df["Month"][i] == 2):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 15 and df["Month"][i] == 4):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 18 and df["Month"][i] == 4):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 23 and df["Month"][i] == 5):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 1 and df["Month"][i] == 7):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 1 and df["Month"][i] == 8):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 5 and df["Month"][i] == 9):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 10 and df["Month"][i] == 10):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 25 and df["Month"][i] == 12):
        df.loc[ i, 'Holiday']  = 1

    elif(df['Dayofmonth'][i] == 26 and df["Month"][i] == 12):
        df.loc[ i, 'Holiday']  = 1


df.index = df["Date"]
df = df.drop(["Date"],axis=1)

# %% [markdown]
# # **Normalize the data**

# %%
columns=["Total Energy Consumption","Day","Month","Q","Dayofmonth","Weekofyear"]
std = df["Total Energy Consumption"].std()
mean = df["Total Energy Consumption"].mean()
df[columns] = (df[columns]-df[columns].mean())/(df[columns].std())

# %% [markdown]
# # **Split the data into training and testing**

# %%
df['Total Energy Consumption'] = df['Total Energy Consumption'].astype(np.float32)
df_train = df[df['Year']<2021]
df_test = df[df['Year']>=2021]

# %% [markdown]
# # **Identify the features that should be used**

# %%
features=["Total Energy Consumption","Day","Weekofyear","Holiday"]#adter testing these features seem to be the most iffective

# %% [markdown]
# # **Transfer DataFrame Elements into Arrays**

# %%
df = df.astype('float32')
power_train = df_train[features].to_numpy()
power_test = df_test[features].to_numpy()
print("Training set has {} observations.".format(len(power_train)))
print("Test set has {} observations.".format(len(power_test)))
# Out:
# Training set has 551 observations.
# Test set has 181 observations.

# %% [markdown]
# # **Fix the issue with values: convert booleans to floats**

# %%
power_train = np.array(power_train)
power_test = np.asarray(power_test)

# %% [markdown]
# # **Create 7 days input and output sequences**

# %%
def supervised_setup(data,column):
  X,y = [], []
  input_start = 0
  n_input = 7
  n_out = 7

  for i in range(len(data)):
    input_end = input_start + n_input
    output_end = input_end + n_out

    if output_end <= len(data):# Each day in the vector has data about the energy consumption at that date, the Day at that Date, the week of the year at that Date, whether the day 7 days after is a Holiday
      x_input = data[input_start:input_end, column:];

      for j in range(0,7):
        x_input[j][-1] = data[input_start + 7:input_end + 7, -1][j]#Is the day 7 days later a Holiday?
      X.append(x_input);

      y.append(data[input_end:output_end,column].reshape((n_out,1)))
    input_start += 1
  return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

# %% [markdown]
# # **Obtain the sequences**

# %%
X_train, y_train = supervised_setup(power_train, 0)
X_test, y_test = supervised_setup(power_test, 0)

# %% [markdown]
# # **Splitting the previous Traing set into a new training set and a validation set**

# %%
from sklearn.model_selection import train_test_split

# Assuming X_train and y_train are already defined

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)  # Adjust test_size and random_state as needed

n_inputs, n_channels, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]
X_ts_train = X_train[:,:,0]
X_ft_train = X_train[:,:,1:]
X_ts_val = X_val[:,:,0]
X_ft_val = X_val[:,:,1:]

# %% [markdown]
# # **TCN Model**

# %%
epochs = 300;
time_series = Input(shape=(n_inputs, 1))
other_feat = Input(shape=(n_inputs, n_channels-1))

conv1 = Conv1D(filters = 3, kernel_size = 2, padding = 'causal', dilation_rate = 5) (time_series)
conv2 = Conv1D(filters = 3, kernel_size = 2, padding = 'same', dilation_rate = 5) (conv1)
conv3 = Conv1D(filters = 3, kernel_size = 2, padding = 'same', dilation_rate = 5) (conv2)
pool = MaxPooling1D(pool_size = 5, strides = 4, padding = 'same') (conv3)
flat_ts = Flatten() (pool)
flat_ft = Flatten() (other_feat)

merged = Concatenate(axis = 1) ([flat_ts, flat_ft])
dense_network = Dense(100, activation = 'linear') (merged)
dense_network = Dense(50, activation = 'linear') (dense_network)
dense_network = Dense(25, activation = 'linear') (dense_network)
output_ts = Dense(7, activation = 'linear') (dense_network)

TCN_funct = Model(inputs = [time_series, other_feat], outputs = output_ts)

TCN_funct.compile(optimizer = 'adam', loss = "mse")

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience= 100, verbose=2, mode='min')
TCN_history = TCN_funct.fit(x = [X_ts_train, X_ft_train], y = y_train, validation_data=[[X_ts_val,X_ft_val], y_val], epochs = epochs, batch_size = 10,callbacks=[monitor])
# Out:
# Epoch 1/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1047 - val_loss: 0.3722
# Epoch 2/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3340 - val_loss: 0.2758
# Epoch 3/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2772 - val_loss: 0.2520
# Epoch 4/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2503 - val_loss: 0.2489
# Epoch 5/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2299 - val_loss: 0.2322
# Epoch 6/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2197 - val_loss: 0.2433
# Epoch 7/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2137 - val_loss: 0.2302
# Epoch 8/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2292 - val_loss: 0.2672
# Epoch 9/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2376 - val_loss: 0.2291
# Epoch 10/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2049 - val_loss: 0.2244
# Epoch 11/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2140 - val_loss: 0.2157
# Epoch 12/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2111 - val_loss: 0.2232
# Epoch 13/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2185 - val_loss: 0.2168
# Epoch 14/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2107 - val_loss: 0.2123
# Epoch 15/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2037 - val_loss: 0.2099
# Epoch 16/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1925 - val_loss: 0.2315
# Epoch 17/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2249 - val_loss: 0.2161
# Epoch 18/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1974 - val_loss: 0.2088
# Epoch 19/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1896 - val_loss: 0.2055
# Epoch 20/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1965 - val_loss: 0.2021
# Epoch 21/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1796 - val_loss: 0.2118
# Epoch 22/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2013 - val_loss: 0.2069
# Epoch 23/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1851 - val_loss: 0.2222
# Epoch 24/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1921 - val_loss: 0.2093
# Epoch 25/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1916 - val_loss: 0.2037
# Epoch 26/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1751 - val_loss: 0.2083
# Epoch 27/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1909 - val_loss: 0.2039
# Epoch 28/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1816 - val_loss: 0.1956
# Epoch 29/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1917 - val_loss: 0.2097
# Epoch 30/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1791 - val_loss: 0.2159
# Epoch 31/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2001 - val_loss: 0.2029
# Epoch 32/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1977 - val_loss: 0.2022
# Epoch 33/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1873 - val_loss: 0.1941
# Epoch 34/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1673 - val_loss: 0.1959
# Epoch 35/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1719 - val_loss: 0.1927
# Epoch 36/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1807 - val_loss: 0.1944
# Epoch 37/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1803 - val_loss: 0.1986
# Epoch 38/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1721 - val_loss: 0.2017
# Epoch 39/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1888 - val_loss: 0.1924
# Epoch 40/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1814 - val_loss: 0.1945
# Epoch 41/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1824 - val_loss: 0.1964
# Epoch 42/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1945 - val_loss: 0.1864
# Epoch 43/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1883 - val_loss: 0.1979
# Epoch 44/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1715 - val_loss: 0.1872
# Epoch 45/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1898 - val_loss: 0.1863
# Epoch 46/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1660 - val_loss: 0.1928
# Epoch 47/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1815 - val_loss: 0.1968
# Epoch 48/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1736 - val_loss: 0.1917
# Epoch 49/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1956 - val_loss: 0.1973
# Epoch 50/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1767 - val_loss: 0.1872
# Epoch 51/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1995 - val_loss: 0.1894
# Epoch 52/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1709 - val_loss: 0.1918
# Epoch 53/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1843 - val_loss: 0.1905
# Epoch 54/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1789 - val_loss: 0.1937
# Epoch 55/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1868 - val_loss: 0.1897
# Epoch 56/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1687 - val_loss: 0.1834
# Epoch 57/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1763 - val_loss: 0.1864
# Epoch 58/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1765 - val_loss: 0.1945
# Epoch 59/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1798 - val_loss: 0.1928
# Epoch 60/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1718 - val_loss: 0.2015
# Epoch 61/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1686 - val_loss: 0.1885
# Epoch 62/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1855 - val_loss: 0.1865
# Epoch 63/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1702 - val_loss: 0.1885
# Epoch 64/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1760 - val_loss: 0.1868
# Epoch 65/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1667 - val_loss: 0.1870
# Epoch 66/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1676 - val_loss: 0.1886
# Epoch 67/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1891 - val_loss: 0.1843
# Epoch 68/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1809 - val_loss: 0.1886
# Epoch 69/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1911 - val_loss: 0.1951
# Epoch 70/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1630 - val_loss: 0.1881
# Epoch 71/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1876 - val_loss: 0.1885
# Epoch 72/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1828 - val_loss: 0.1912
# Epoch 73/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1613 - val_loss: 0.1898
# Epoch 74/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1728 - val_loss: 0.1857
# Epoch 75/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1813 - val_loss: 0.1929
# Epoch 76/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1927 - val_loss: 0.1883
# Epoch 77/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1881 - val_loss: 0.1887
# Epoch 78/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1711 - val_loss: 0.1890
# Epoch 79/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1667 - val_loss: 0.1953
# Epoch 80/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1821 - val_loss: 0.1910
# Epoch 81/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1705 - val_loss: 0.1887
# Epoch 82/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1653 - val_loss: 0.1946
# Epoch 83/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1781 - val_loss: 0.1879
# Epoch 84/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1630 - val_loss: 0.1928
# Epoch 85/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1773 - val_loss: 0.1845
# Epoch 86/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1660 - val_loss: 0.1898
# Epoch 87/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1766 - val_loss: 0.1928
# Epoch 88/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1783 - val_loss: 0.1827
# Epoch 89/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1660 - val_loss: 0.1868
# Epoch 90/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1712 - val_loss: 0.1838
# Epoch 91/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1794 - val_loss: 0.1907
# Epoch 92/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1687 - val_loss: 0.1840
# Epoch 93/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1696 - val_loss: 0.1881
# Epoch 94/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1884 - val_loss: 0.1892
# Epoch 95/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1727 - val_loss: 0.1860
# Epoch 96/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1730 - val_loss: 0.2039
# Epoch 97/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1811 - val_loss: 0.1857
# Epoch 98/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1691 - val_loss: 0.1828
# Epoch 99/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1918 - val_loss: 0.1866
# Epoch 100/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1760 - val_loss: 0.1851
# Epoch 101/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1654 - val_loss: 0.1849
# Epoch 102/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1851 - val_loss: 0.1817
# Epoch 103/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1806 - val_loss: 0.1844
# Epoch 104/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1810 - val_loss: 0.1934
# Epoch 105/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1832 - val_loss: 0.1939
# Epoch 106/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1643 - val_loss: 0.1946
# Epoch 107/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1761 - val_loss: 0.1837
# Epoch 108/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1602 - val_loss: 0.1924
# Epoch 109/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1715 - val_loss: 0.1800
# Epoch 110/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1606 - val_loss: 0.1905
# Epoch 111/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1713 - val_loss: 0.1899
# Epoch 112/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1806 - val_loss: 0.1887
# Epoch 113/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1742 - val_loss: 0.1854
# Epoch 114/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1712 - val_loss: 0.1831
# Epoch 115/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1799 - val_loss: 0.1911
# Epoch 116/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1760 - val_loss: 0.1895
# Epoch 117/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1623 - val_loss: 0.1842
# Epoch 118/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1699 - val_loss: 0.1873
# Epoch 119/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1704 - val_loss: 0.1884
# Epoch 120/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1714 - val_loss: 0.1869
# Epoch 121/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1679 - val_loss: 0.1900
# Epoch 122/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1661 - val_loss: 0.1934
# Epoch 123/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1661 - val_loss: 0.1887
# Epoch 124/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1724 - val_loss: 0.1830
# Epoch 125/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1683 - val_loss: 0.1827
# Epoch 126/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1750 - val_loss: 0.1859
# Epoch 127/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1735 - val_loss: 0.1830
# Epoch 128/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1606 - val_loss: 0.1823
# Epoch 129/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1821 - val_loss: 0.1870
# Epoch 130/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1736 - val_loss: 0.1866
# Epoch 131/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1723 - val_loss: 0.1851
# Epoch 132/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1770 - val_loss: 0.1912
# Epoch 133/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1773 - val_loss: 0.1873
# Epoch 134/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1610 - val_loss: 0.1844
# Epoch 135/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1795 - val_loss: 0.1862
# Epoch 136/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1753 - val_loss: 0.1848
# Epoch 137/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1760 - val_loss: 0.1816
# Epoch 138/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1805 - val_loss: 0.1875
# Epoch 139/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1715 - val_loss: 0.1824
# Epoch 140/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1660 - val_loss: 0.1912
# Epoch 141/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1897 - val_loss: 0.1935
# Epoch 142/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1817 - val_loss: 0.1862
# Epoch 143/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1805 - val_loss: 0.1851
# Epoch 144/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1619 - val_loss: 0.1882
# Epoch 145/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1673 - val_loss: 0.1942
# Epoch 146/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1702 - val_loss: 0.1912
# Epoch 147/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1617 - val_loss: 0.1888
# Epoch 148/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1753 - val_loss: 0.1831
# Epoch 149/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1589 - val_loss: 0.1806
# Epoch 150/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1655 - val_loss: 0.1848
# Epoch 151/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1662 - val_loss: 0.1895
# Epoch 152/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1671 - val_loss: 0.1851
# Epoch 153/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1685 - val_loss: 0.1944
# Epoch 154/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1738 - val_loss: 0.1850
# Epoch 155/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1657 - val_loss: 0.1853
# Epoch 156/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1585 - val_loss: 0.1922
# Epoch 157/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1537 - val_loss: 0.1948
# Epoch 158/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1511 - val_loss: 0.1872
# Epoch 159/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1701 - val_loss: 0.1875
# Epoch 160/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1681 - val_loss: 0.1902
# Epoch 161/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1648 - val_loss: 0.1865
# Epoch 162/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1677 - val_loss: 0.1819
# Epoch 163/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1792 - val_loss: 0.1867
# Epoch 164/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1706 - val_loss: 0.1891
# Epoch 165/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1661 - val_loss: 0.2003
# Epoch 166/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1710 - val_loss: 0.1833
# Epoch 167/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1588 - val_loss: 0.1797
# Epoch 168/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1782 - val_loss: 0.1840
# Epoch 169/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1688 - val_loss: 0.1854
# Epoch 170/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1772 - val_loss: 0.1809
# Epoch 171/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1646 - val_loss: 0.1822
# Epoch 172/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1630 - val_loss: 0.1910
# Epoch 173/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1630 - val_loss: 0.1889
# Epoch 174/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1747 - val_loss: 0.1903
# Epoch 175/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1743 - val_loss: 0.1873
# Epoch 176/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1621 - val_loss: 0.1821
# Epoch 177/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1537 - val_loss: 0.1853
# Epoch 178/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1624 - val_loss: 0.1821
# Epoch 179/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1610 - val_loss: 0.1893
# Epoch 180/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1833 - val_loss: 0.1817
# Epoch 181/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1691 - val_loss: 0.1864
# Epoch 182/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1629 - val_loss: 0.1859
# Epoch 183/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1649 - val_loss: 0.1803
# Epoch 184/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1736 - val_loss: 0.1810
# Epoch 185/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1642 - val_loss: 0.1869
# Epoch 186/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1827 - val_loss: 0.1867
# Epoch 187/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1624 - val_loss: 0.1929
# Epoch 188/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1731 - val_loss: 0.1811
# Epoch 189/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1638 - val_loss: 0.1842
# Epoch 190/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1884 - val_loss: 0.1867
# Epoch 191/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1613 - val_loss: 0.1829
# Epoch 192/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1623 - val_loss: 0.1788
# Epoch 193/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1767 - val_loss: 0.1869
# Epoch 194/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1754 - val_loss: 0.1801
# Epoch 195/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1829 - val_loss: 0.1832
# Epoch 196/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1730 - val_loss: 0.1847
# Epoch 197/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1788 - val_loss: 0.1799
# Epoch 198/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1549 - val_loss: 0.1861
# Epoch 199/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1612 - val_loss: 0.1837
# Epoch 200/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1737 - val_loss: 0.1860
# Epoch 201/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1699 - val_loss: 0.1828
# Epoch 202/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1727 - val_loss: 0.1923
# Epoch 203/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1802 - val_loss: 0.1828
# Epoch 204/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1702 - val_loss: 0.1824
# Epoch 205/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1809 - val_loss: 0.1919
# Epoch 206/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1806 - val_loss: 0.1850
# Epoch 207/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1693 - val_loss: 0.1931
# Epoch 208/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1816 - val_loss: 0.1815
# Epoch 209/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1691 - val_loss: 0.1832
# Epoch 210/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1862 - val_loss: 0.1801
# Epoch 211/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1698 - val_loss: 0.1920
# Epoch 212/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1863 - val_loss: 0.1833
# Epoch 213/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1690 - val_loss: 0.1859
# Epoch 214/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1643 - val_loss: 0.1832
# Epoch 215/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1705 - val_loss: 0.1836
# Epoch 216/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1643 - val_loss: 0.1806
# Epoch 217/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1561 - val_loss: 0.1833
# Epoch 218/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1678 - val_loss: 0.1895
# Epoch 219/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1580 - val_loss: 0.1810
# Epoch 220/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1710 - val_loss: 0.1887
# Epoch 221/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1765 - val_loss: 0.1801
# Epoch 222/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1641 - val_loss: 0.1860
# Epoch 223/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1682 - val_loss: 0.1819
# Epoch 224/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1733 - val_loss: 0.1811
# Epoch 225/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1773 - val_loss: 0.1903
# Epoch 226/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1773 - val_loss: 0.1816
# Epoch 227/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1633 - val_loss: 0.1890
# Epoch 228/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1736 - val_loss: 0.1906
# Epoch 229/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1668 - val_loss: 0.1785
# Epoch 230/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1697 - val_loss: 0.1817
# Epoch 231/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1559 - val_loss: 0.1833
# Epoch 232/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1701 - val_loss: 0.1810
# Epoch 242/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1648 - val_loss: 0.1818
# Epoch 243/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1672 - val_loss: 0.1768
# Epoch 244/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1718 - val_loss: 0.1844
# Epoch 245/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1600 - val_loss: 0.1810
# Epoch 246/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1724 - val_loss: 0.1802
# Epoch 247/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1707 - val_loss: 0.1826
# Epoch 248/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1646 - val_loss: 0.1869
# Epoch 249/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1648 - val_loss: 0.1828
# Epoch 250/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1616 - val_loss: 0.1814
# Epoch 251/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1610 - val_loss: 0.1833
# Epoch 252/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1671 - val_loss: 0.1792
# Epoch 253/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1663 - val_loss: 0.1827
# Epoch 254/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1551 - val_loss: 0.1846
# Epoch 255/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1634 - val_loss: 0.1822
# Epoch 256/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1825 - val_loss: 0.1806
# Epoch 257/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1671 - val_loss: 0.1828
# Epoch 258/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1582 - val_loss: 0.1797
# Epoch 259/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1671 - val_loss: 0.1824
# Epoch 260/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1679 - val_loss: 0.1832
# Epoch 261/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1689 - val_loss: 0.1791
# Epoch 262/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1649 - val_loss: 0.1818
# Epoch 263/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1634 - val_loss: 0.1819
# Epoch 264/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1572 - val_loss: 0.1826
# Epoch 265/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1749 - val_loss: 0.1810
# Epoch 266/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1614 - val_loss: 0.1840
# Epoch 267/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1685 - val_loss: 0.1824
# Epoch 268/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1775 - val_loss: 0.1792
# Epoch 269/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1634 - val_loss: 0.1845
# Epoch 270/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1671 - val_loss: 0.1829
# Epoch 271/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1627 - val_loss: 0.1773
# Epoch 272/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1674 - val_loss: 0.1795
# Epoch 273/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1699 - val_loss: 0.1847
# Epoch 274/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1737 - val_loss: 0.1804
# Epoch 275/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1717 - val_loss: 0.1857
# Epoch 276/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1799 - val_loss: 0.1808
# Epoch 277/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1666 - val_loss: 0.1822
# Epoch 278/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1684 - val_loss: 0.1844
# Epoch 279/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1693 - val_loss: 0.1850
# Epoch 280/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1729 - val_loss: 0.1843
# Epoch 281/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1662 - val_loss: 0.1783
# Epoch 282/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1644 - val_loss: 0.1838
# Epoch 283/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1613 - val_loss: 0.1781
# Epoch 284/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1639 - val_loss: 0.1803
# Epoch 285/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1611 - val_loss: 0.1811
# Epoch 286/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1609 - val_loss: 0.1894
# Epoch 287/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1672 - val_loss: 0.1826
# Epoch 288/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1727 - val_loss: 0.1843
# Epoch 289/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1648 - val_loss: 0.1895
# Epoch 290/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1594 - val_loss: 0.1836
# Epoch 291/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1599 - val_loss: 0.1829
# Epoch 292/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1637 - val_loss: 0.1884
# Epoch 293/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1649 - val_loss: 0.1800
# Epoch 294/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1635 - val_loss: 0.1784
# Epoch 295/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1686 - val_loss: 0.1808
# Epoch 296/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1663 - val_loss: 0.1854
# Epoch 297/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1577 - val_loss: 0.1855
# Epoch 298/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1777 - val_loss: 0.1810
# Epoch 299/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1844 - val_loss: 0.1786
# Epoch 300/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1542 - val_loss: 0.1856

# %%
plot_model(TCN_funct, to_file='functional TCN model.png', show_shapes=True, show_dtype=False, show_layer_names=False, show_layer_activations=True)

# %% [markdown]
# # **TCN Model evalution on training and validation set**

# %%
# cell that plots averaged predictions
y_predict_train= TCN_funct.predict([X_ts_train, X_ft_train])
y_tren= y_train[7:-6,0,0]
plotted_days=y_train.shape[0]-6*2
y_pred=[]
for d in range(0,plotted_days):
  prediction = 0
  for i in [0,1,2,3,4,5,6]:
    prediction = prediction + y_predict_train[d+i,6-i]
  prediction = prediction/7
  y_pred.append(prediction)
  plt.figure(num=1, figsize=[10,5])
  plt.plot(y_tren[98:130],color="blue")
  plt.plot(y_pred[98:130],color="red")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# # **Defined function used to measure multiple evaluation metrics**

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual)); mse = mean_squared_error(actual,forecast)
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None],
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None],
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae,
            'mpe': mpe, 'rmse':rmse,
            'corr':corr, 'minmax':minmax, 'mse':mse})

# %% [markdown]
# # **First Day prediction evaluation**

# %%
y_predict_test = TCN_funct.predict([X_ts_val, X_ft_val])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i][0])
  y2.append(y_val[i][0])
forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean ## Return data into the intial range before normalization
actual = actual*std + mean

plt.plot(actual,color="blue", label="Expected")
plt.plot(forcast,color="red", label="Predicted")
plt.legend(loc="upper right")
plt.title("Training Data: Day 1")

print(forecast_accuracy(forcast, actual))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'mape': 0.02353785, 'me': 1667.8414, 'mae': 11569.561, 'mpe': 0.004366491, 'rmse': 15788.283757267602, 'corr': 0.9534206978651629, 'minmax': 0.02283930778503418, 'mse': 249269900.0}

# %% [markdown]
# # **7th Day prediction evaluation**

# %%
y_predict_test = TCN_funct.predict([X_ts_val, X_ft_val])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i][6])
  y2.append(y_val[i][6])
forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean ## Return data into the intial range before normalization
actual = actual*std + mean

plt.plot(actual,color="blue", label="Expected")
plt.plot(forcast,color="red", label="Predicted")
plt.legend(loc="upper right")
plt.title("Validation Data: Day 7")

print(forecast_accuracy(forcast, actual))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'mape': 0.03977985, 'me': -336.45255, 'mae': 20125.963, 'mpe': 0.0028402836, 'rmse': 25655.292787259317, 'corr': 0.8945400270074354, 'minmax': 0.03844296932220459, 'mse': 658194050.0}

# %% [markdown]
# # **Total Average prediction evaluation**

# %%
y_predict_test = TCN_funct.predict([X_ts_val, X_ft_val])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i].sum()/7)
  y2.append(y_val[i].sum()/7)
forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean ## Return data into the intial range before normalization
actual = actual*std + mean

print(forecast_accuracy(forcast, actual))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'mape': 0.024830155642540867, 'me': 347.53655750774004, 'mae': 12451.054280728338, 'mpe': 0.002272463544900246, 'rmse': 16124.98542277972, 'corr': 0.9426043515299345, 'minmax': 0.024252145570112016, 'mse': 260015154.8848585}

# %% [markdown]
# # **LSTM Model**

# %%
n_inputs, n_channels, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]
n_cells = 50
epochs =  300;
time_series = Input(shape=(n_inputs, 1))
other_feat = Input(shape=(n_inputs, n_channels-1))

conv1 = LSTM(n_cells, activation='linear', input_shape=(n_inputs,7), return_sequences=True)(time_series)
flat_ts = Flatten() (conv1)
flat_ft = Flatten() (other_feat)
merged = Concatenate(axis = 1) ([flat_ts, flat_ft])
dense_network = Dense(100, activation = 'linear')(merged)
dense_network = Dense(50, activation = 'linear')(dense_network)
dense_network = Dense(25, activation = 'linear')(dense_network)
output_ts = Dense(7, activation = 'linear') (dense_network)
LSTM_funct = Model(inputs = [time_series, other_feat], outputs = output_ts)
LSTM_funct.compile(optimizer = 'adam', loss = "mse")
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=100, verbose=2, mode='min')
LSTM_history = LSTM_funct.fit(x = [X_ts_train, X_ft_train], y = y_train, validation_data=[[X_ts_val,X_ft_val], y_val], epochs = epochs, batch_size = 10, callbacks=[monitor])
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5708 - val_loss: 0.2980
# Epoch 2/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2758 - val_loss: 0.2756
# Epoch 3/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2303 - val_loss: 0.2301
# Epoch 4/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2481 - val_loss: 0.2335
# Epoch 5/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2165 - val_loss: 0.2284
# Epoch 6/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2152 - val_loss: 0.2186
# Epoch 7/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2019 - val_loss: 0.2169
# Epoch 8/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2100 - val_loss: 0.2112
# Epoch 9/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2127 - val_loss: 0.2243
# Epoch 10/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2059 - val_loss: 0.2166
# Epoch 11/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1931 - val_loss: 0.2131
# Epoch 12/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1993 - val_loss: 0.2320
# Epoch 13/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1863 - val_loss: 0.2203
# Epoch 14/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1997 - val_loss: 0.2067
# Epoch 15/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1927 - val_loss: 0.2126
# Epoch 16/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2014 - val_loss: 0.2102
# Epoch 17/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1904 - val_loss: 0.2123
# Epoch 18/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1765 - val_loss: 0.2049
# Epoch 19/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1812 - val_loss: 0.2215
# Epoch 20/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1712 - val_loss: 0.2194
# Epoch 21/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1695 - val_loss: 0.2086
# Epoch 22/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1750 - val_loss: 0.2256
# Epoch 23/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1798 - val_loss: 0.2061
# Epoch 24/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1867 - val_loss: 0.2157
# Epoch 25/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1850 - val_loss: 0.2090
# Epoch 26/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1913 - val_loss: 0.1978
# Epoch 27/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1639 - val_loss: 0.1992
# Epoch 28/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2015 - val_loss: 0.1996
# Epoch 29/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1660 - val_loss: 0.2018
# Epoch 30/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1863 - val_loss: 0.2057
# Epoch 31/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1699 - val_loss: 0.2017
# Epoch 32/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1978 - val_loss: 0.2045
# Epoch 33/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1845 - val_loss: 0.1915
# Epoch 34/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1726 - val_loss: 0.1928
# Epoch 35/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1666 - val_loss: 0.1966
# Epoch 36/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1812 - val_loss: 0.1908
# Epoch 37/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1642 - val_loss: 0.2007
# Epoch 38/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1872 - val_loss: 0.1909
# Epoch 39/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1673 - val_loss: 0.1950
# Epoch 40/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1770 - val_loss: 0.1952
# Epoch 41/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1743 - val_loss: 0.1904
# Epoch 42/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1588 - val_loss: 0.1926
# Epoch 43/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1676 - val_loss: 0.1862
# Epoch 44/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1688 - val_loss: 0.1895
# Epoch 45/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1591 - val_loss: 0.1891
# Epoch 46/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1785 - val_loss: 0.1891
# Epoch 47/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1724 - val_loss: 0.1876
# Epoch 48/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1716 - val_loss: 0.1910
# Epoch 49/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1718 - val_loss: 0.1830
# Epoch 50/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1658 - val_loss: 0.1880
# Epoch 51/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1710 - val_loss: 0.1832
# Epoch 52/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1621 - val_loss: 0.1902
# Epoch 53/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1576 - val_loss: 0.1838
# Epoch 54/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1559 - val_loss: 0.1795
# Epoch 55/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1751 - val_loss: 0.1814
# Epoch 56/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1685 - val_loss: 0.1876
# Epoch 57/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1844 - val_loss: 0.1883
# Epoch 58/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1518 - val_loss: 0.1842
# Epoch 59/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1606 - val_loss: 0.1761
# Epoch 60/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1557 - val_loss: 0.1852
# Epoch 61/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1545 - val_loss: 0.1782
# Epoch 62/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1606 - val_loss: 0.1949
# Epoch 63/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1676 - val_loss: 0.1838
# Epoch 64/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1526 - val_loss: 0.1797
# Epoch 65/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1532 - val_loss: 0.1808
# Epoch 66/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1531 - val_loss: 0.1856
# Epoch 67/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1598 - val_loss: 0.1885
# Epoch 68/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1597 - val_loss: 0.1770
# Epoch 69/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1689 - val_loss: 0.1741
# Epoch 70/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1571 - val_loss: 0.1770
# Epoch 71/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1604 - val_loss: 0.1857
# Epoch 72/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1601 - val_loss: 0.1860
# Epoch 73/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1754 - val_loss: 0.1777
# Epoch 74/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1571 - val_loss: 0.1748
# Epoch 75/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1450 - val_loss: 0.1743
# Epoch 76/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1722 - val_loss: 0.1791
# Epoch 77/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1518 - val_loss: 0.1828
# Epoch 78/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1596 - val_loss: 0.1798
# Epoch 79/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1556 - val_loss: 0.1792
# Epoch 80/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1654 - val_loss: 0.1773
# Epoch 81/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1527 - val_loss: 0.1730
# Epoch 82/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1426 - val_loss: 0.1735
# Epoch 83/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1422 - val_loss: 0.1811
# Epoch 84/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1576 - val_loss: 0.1820
# Epoch 85/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1537 - val_loss: 0.1793
# Epoch 86/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1440 - val_loss: 0.1750
# Epoch 87/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1527 - val_loss: 0.1778
# Epoch 88/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1633 - val_loss: 0.1739
# Epoch 89/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1630 - val_loss: 0.1795
# Epoch 90/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1543 - val_loss: 0.1746
# Epoch 91/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1494 - val_loss: 0.1803
# Epoch 92/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1581 - val_loss: 0.1748
# Epoch 93/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1433 - val_loss: 0.1753
# Epoch 94/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1512 - val_loss: 0.1799
# Epoch 95/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1578 - val_loss: 0.1758
# Epoch 96/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1519 - val_loss: 0.1749
# Epoch 97/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1362 - val_loss: 0.1785
# Epoch 98/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1534 - val_loss: 0.1815
# Epoch 99/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1542 - val_loss: 0.1776
# Epoch 100/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1452 - val_loss: 0.1834
# Epoch 101/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1516 - val_loss: 0.1850
# Epoch 102/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1428 - val_loss: 0.1700
# Epoch 103/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1394 - val_loss: 0.1753
# Epoch 104/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1520 - val_loss: 0.1795
# Epoch 105/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1475 - val_loss: 0.1724
# Epoch 106/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1527 - val_loss: 0.1751
# Epoch 107/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1442 - val_loss: 0.1867
# Epoch 108/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1422 - val_loss: 0.1788
# Epoch 109/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1479 - val_loss: 0.1770
# Epoch 110/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1536 - val_loss: 0.1717
# Epoch 111/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1480 - val_loss: 0.1808
# Epoch 112/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1485 - val_loss: 0.1780
# Epoch 113/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1361 - val_loss: 0.1778
# Epoch 114/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1362 - val_loss: 0.1817
# Epoch 115/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1480 - val_loss: 0.1750
# Epoch 116/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1484 - val_loss: 0.1764
# Epoch 117/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1469 - val_loss: 0.1769
# Epoch 118/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1511 - val_loss: 0.1744
# Epoch 119/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1576 - val_loss: 0.1724
# Epoch 120/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1415 - val_loss: 0.1721
# Epoch 121/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1467 - val_loss: 0.1727
# Epoch 122/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1446 - val_loss: 0.1713
# Epoch 123/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1331 - val_loss: 0.1791
# Epoch 124/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1541 - val_loss: 0.1717
# Epoch 125/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1456 - val_loss: 0.1743
# Epoch 126/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1435 - val_loss: 0.1722
# Epoch 127/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1408 - val_loss: 0.1804
# Epoch 128/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1510 - val_loss: 0.1740
# Epoch 129/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1409 - val_loss: 0.1768
# Epoch 130/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1353 - val_loss: 0.1750
# Epoch 131/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1446 - val_loss: 0.1816
# Epoch 132/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1445 - val_loss: 0.1748
# Epoch 133/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1523 - val_loss: 0.1783
# Epoch 134/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1432 - val_loss: 0.1843
# Epoch 135/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1450 - val_loss: 0.1736
# Epoch 136/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1527 - val_loss: 0.1776
# Epoch 137/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1407 - val_loss: 0.1711
# Epoch 138/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1457 - val_loss: 0.1736
# Epoch 139/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1564 - val_loss: 0.1709
# Epoch 140/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1652 - val_loss: 0.1744
# Epoch 141/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1408 - val_loss: 0.1724
# Epoch 142/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1469 - val_loss: 0.1740
# Epoch 143/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1488 - val_loss: 0.1719
# Epoch 144/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1433 - val_loss: 0.1773
# Epoch 145/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1501 - val_loss: 0.1757
# Epoch 146/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1512 - val_loss: 0.1764
# Epoch 147/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1383 - val_loss: 0.1732
# Epoch 148/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1324 - val_loss: 0.1792
# Epoch 149/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1323 - val_loss: 0.1753
# Epoch 150/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1448 - val_loss: 0.1721
# Epoch 151/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1320 - val_loss: 0.1724
# Epoch 152/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1419 - val_loss: 0.1731
# Epoch 153/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1417 - val_loss: 0.1801
# Epoch 154/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1492 - val_loss: 0.1765
# Epoch 155/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1531 - val_loss: 0.1756
# Epoch 156/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1477 - val_loss: 0.1728
# Epoch 157/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1414 - val_loss: 0.1735
# Epoch 158/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1552 - val_loss: 0.1768
# Epoch 159/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1408 - val_loss: 0.1719
# Epoch 160/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1473 - val_loss: 0.1745
# Epoch 161/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1308 - val_loss: 0.1797
# Epoch 162/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1428 - val_loss: 0.1767
# Epoch 163/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1341 - val_loss: 0.1742
# Epoch 164/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1348 - val_loss: 0.1779
# Epoch 165/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1349 - val_loss: 0.1708
# Epoch 166/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1474 - val_loss: 0.1786
# Epoch 167/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1316 - val_loss: 0.1722
# Epoch 168/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1474 - val_loss: 0.1836
# Epoch 169/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1447 - val_loss: 0.1721
# Epoch 170/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1393 - val_loss: 0.1752
# Epoch 171/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1500 - val_loss: 0.1753
# Epoch 172/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1423 - val_loss: 0.1709
# Epoch 173/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1272 - val_loss: 0.1725
# Epoch 174/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1529 - val_loss: 0.1766
# Epoch 175/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1434 - val_loss: 0.1763
# Epoch 176/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1351 - val_loss: 0.1720
# Epoch 177/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1299 - val_loss: 0.1860
# Epoch 178/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1310 - val_loss: 0.1753
# Epoch 179/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1317 - val_loss: 0.1851
# Epoch 180/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1417 - val_loss: 0.1790
# Epoch 181/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1377 - val_loss: 0.1737
# Epoch 182/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1484 - val_loss: 0.1697
# Epoch 183/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1306 - val_loss: 0.1812
# Epoch 184/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1413 - val_loss: 0.1722
# Epoch 185/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1432 - val_loss: 0.1810
# Epoch 186/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1383 - val_loss: 0.1710
# Epoch 187/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1339 - val_loss: 0.1720
# Epoch 188/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1417 - val_loss: 0.1794
# Epoch 189/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1491 - val_loss: 0.1828
# Epoch 190/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1351 - val_loss: 0.1852
# Epoch 191/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1398 - val_loss: 0.1736
# Epoch 192/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1293 - val_loss: 0.1741
# Epoch 193/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1322 - val_loss: 0.1753
# Epoch 194/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1472 - val_loss: 0.1787
# Epoch 195/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1435 - val_loss: 0.1717
# Epoch 196/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1415 - val_loss: 0.1699
# Epoch 197/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1382 - val_loss: 0.1745
# Epoch 198/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1409 - val_loss: 0.1703
# Epoch 199/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1393 - val_loss: 0.1763
# Epoch 200/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1345 - val_loss: 0.1744
# Epoch 201/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1499 - val_loss: 0.1762
# Epoch 202/300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1385 - val_loss: 0.1746
# Epoch 202: early stopping

# %%
plot_model(LSTM_funct, to_file='functional LSTM model.png', show_shapes=True, show_dtype=False, show_layer_names=False, show_layer_activations=True)

# %% [markdown]
# # **LSTM Model evalution on training and validation set**

# %%
# cell that plots averaged predictions
y_predict_train= LSTM_funct.predict([X_ts_train, X_ft_train])
y_tren= y_train[7:-6,0,0]
plotted_days=y_train.shape[0]-6*2
y_pred=[]
for d in range(0,plotted_days):
  #y_pred= y_predict_train[:,d]
  prediction = 0
  for i in [0,1,2,3,4,5,6]:
    prediction = prediction + y_predict_train[d+i,6-i]
  prediction = prediction/7
  y_pred.append(prediction)
  plt.figure(num=1, figsize=[18,8])
  plt.plot(y_tren,color="blue")
  plt.plot(y_pred,color="red")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# # **First Day prediction evaluation**

# %%
y_predict_test = LSTM_funct.predict([X_ts_val, X_ft_val])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i][0])
  y2.append(y_val[i][0])
forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean ## Return data into the intial range before normalization
actual = actual*std + mean

plt.plot(actual,color="blue", label="Expected")
plt.plot(forcast,color="red", label="Predicted")
plt.legend(loc="upper right")
plt.title("Validation Data: Day 1")

print(forecast_accuracy(forcast, actual))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# {'mape': 0.024456503, 'me': -3376.5862, 'mae': 12319.788, 'mpe': -0.006137646, 'rmse': 16527.933204124463, 'corr': 0.951584821637398, 'minmax': 0.024073123931884766, 'mse': 273172580.0}

# %% [markdown]
# # **7th Day prediction evaluation**

# %%
y_predict_test = LSTM_funct.predict([X_ts_val, X_ft_val])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i][6])
  y2.append(y_val[i][6])
forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean ## Return data into the intial range before normalization
actual = actual*std + mean

plt.plot(actual,color="blue", label="Expected")
plt.plot(forcast,color="red", label="Predicted")
plt.legend(loc="upper right")
plt.title("Validation Data: Day 7")

print(forecast_accuracy(forcast, actual))

print(forecast_accuracy(forcast, actual))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# {'mape': 0.03865883, 'me': -3413.6877, 'mae': 19830.467, 'mpe': -0.0050988346, 'rmse': 26577.1848020064, 'corr': 0.8875759707297176, 'minmax': 0.037588417530059814, 'mse': 706346750.0}
# {'mape': 0.03865883, 'me': -3413.6877, 'mae': 19830.467, 'mpe': -0.0050988346, 'rmse': 26577.1848020064, 'corr': 0.8875759707297176, 'minmax': 0.037588417530059814, 'mse': 706346750.0}

# %% [markdown]
# # **Total Average prediction evaluation**

# %%
y_predict_test = LSTM_funct.predict([X_ts_val, X_ft_val])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i].sum()/7)
  y2.append(y_val[i].sum()/7)
forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean ## Return data into the intial range before normalization
actual = actual*std + mean

print(forecast_accuracy(forcast, actual))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# {'mape': 0.023418752064980976, 'me': -1910.078207509977, 'mae': 11948.167578619481, 'mpe': -0.003051590052485864, 'rmse': 15406.838544091497, 'corr': 0.9468135760902533, 'minmax': 0.023027280946410822, 'mse': 237370673.92370343}

# %% [markdown]
# # **Comparing all Models using Test set**

# %%
X_ts_test = X_test[:,:,0]
X_ft_test = X_test[:,:,1:]
y_predict_test = TCN_funct.predict([X_ts_test, X_ft_test])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i].sum()/7)
  y2.append(y_test[i].sum()/7)

forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean
actual = actual*std + mean


print(forecast_accuracy(forcast, actual))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'mape': 0.028790021752829936, 'me': -4685.266431371266, 'mae': 14285.728435543582, 'mpe': -0.008642703377869081, 'rmse': 18612.403779490563, 'corr': 0.6478423414998014, 'minmax': 0.02823677167063854, 'mse': 346421574.45079464}

# %%
y_predict_test = LSTM_funct.predict([X_ts_test, X_ft_test])
y1 = []
y2 = []
for i in range(0,y_predict_test.shape[0]):
  y1.append(y_predict_test[i].sum()/7)
  y2.append(y_test[i].sum()/7)

forcast = np.array(y1)
actual = np.array(y2)
actual = actual.flatten()
forcast = forcast*std + mean
actual = actual*std + mean

print(forecast_accuracy(forcast, actual))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# {'mape': 0.027703896278214398, 'me': -3572.2158200839226, 'mae': 13749.173934599428, 'mpe': -0.006506087195016428, 'rmse': 19007.218832534832, 'corr': 0.649980910635475, 'minmax': 0.027078658957191082, 'mse': 361274367.74786675}
